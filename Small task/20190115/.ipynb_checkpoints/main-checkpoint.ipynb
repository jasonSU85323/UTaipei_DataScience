# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # 原始資料

# %%
data = pd.read_csv(r'C:\Users\jasonsu\Documents\4.Gitthub\UTaipei_DataScience\Small task\20190115\AppleStore.csv')
data.head(5)
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %% [markdown]
# # 在Excel篩選
# 選擇免費：price = 0
# 平均用戶評分值為0與5：user_rating = 0 & 5
# 取出「prime_gener」欄位

# %%
data = pd.read_csv(r'C:\Users\jasonsu\Documents\4.Gitthub\UTaipei_DataScience\Small task\20190115\0.csv')
data.head(5)
# Out:
#   prime_genre
# 0     Finance
# 1        Book
# 2      Travel
# 3  Navigation
# 4   Education

# %%
data = pd.read_csv(r'C:\Users\jasonsu\Documents\4.Gitthub\UTaipei_DataScience\Small task\20190115\5.csv')
data.head(5)
# Out:
#      prime_genre
# 0      Utilities
# 1       Shopping
# 2           News
# 3  Photo & Video
# 4      Utilities

# %% [markdown]
# # 計算prime_gener欄位計數
# 使用shell方式：
#
# * cat 0.csv | awk -F, '{print $1}' | sort | uniq -c | awk -F' ' '{print $1","$2}' >> 0_ok.csv
#
# * cat 5.csv | awk -F, '{print $1}' | sort | uniq -c | awk -F' ' '{print $1","$2}' >> 5_ok.csv

# %%
data = pd.read_csv(r'C:\Users\jasonsu\Documents\4.Gitthub\UTaipei_DataScience\Small task\20190115\0_ok.csv')
data.head(5)
# Out:
#    COUNT           NAME
# 0     47           Book
# 1      4       Business
# 2      5       Catalogs
# 3     66      Education
# 4     64  Entertainment

# %%
data = pd.read_csv(r'C:\Users\jasonsu\Documents\4.Gitthub\UTaipei_DataScience\Small task\20190115\5_ok.csv')
data.head(5)
# Out:
#    COUNT           NAME
# 0      6           Book
# 1      2       Business
# 2      1       Catalogs
# 3      5      Education
# 4     14  Entertainment

# %% [markdown]
# # 合成「0-5.csv」

# %%
data = pd.read_csv(r'C:\Users\jasonsu\Documents\4.Gitthub\UTaipei_DataScience\Small task\20190115\0-5.csv')
data.head(100)
# Out:
#              NAME  COUNT    0    5
# 0            Book     53   47    6
# 1        Business      6    4    2
# 2        Catalogs      6    5    1
# 3       Education     71   66    5
# 4   Entertainment     78   64   14
# 5         Finance     36   33    3
# 6            Food     13   11    2
# 7           Games    612  462  150
# 8          Health     33   21   12
# 9       Lifestyle     35   31    4
# 10        Medical      5    3    2
# 11          Music      4    4    0
# 12     Navigation     15   15    0
# 13           News     16   15    1
# 14          Photo     45   24   21
# 15    prime_genre      2    1    1
# 16   Productivity     10    6    4
# 17      Reference     11   11    0
# 18       Shopping     28   16   12
# 19         Social     37   33    4
# 20         Sports     14   13    1
# 21         Travel     14   10    4
# 22      Utilities     36   29    7
# 23        Weather      6    6    0

# %%
fig = plt.figure(figsize=(15, 7))
ax1 = fig.add_subplot(111)

for (i, row) in data.iterrows():
    plt.bar([i, i], [row['5'], -row['0']],
            color=['#CC6699', '#008AB8'], width=0.8, align='center', edgecolor='none')
    
plt.xlim(-0.6, 20.6)
plt.ylim(-500, 500)
#plt.grid(False, axis='x')
plt.xticks(np.arange(0, 21), data['NAME'], fontsize=11, rotation=45)
plt.yticks(np.arange(-500, 500, 50),
           ['{}'.format(int(abs(x))) if x != 0 else 0 for x in np.arange(-500, 500, 50)])
plt.xlabel('prime genre')
plt.ylabel('Number of comments')

plt.savefig('ya.pdf')
;
# Out:
# ''

# %%
fig = plt.figure(figsize=(15, 7))
ax1 = fig.add_subplot(111)

for (i, row) in data.iterrows():
    plt.bar([i - 0.2, i + 0.2], [row['5'], row['0']],
            color=['#CC6699', '#008AB8'], width=0.4, align='center', edgecolor='none')
    
plt.xlim(-0.6, 20.6)
plt.xticks(range(0, 21), data['NAME'], fontsize=11, rotation=45)
plt.grid(False, axis='x')
plt.yticks(np.arange(0, 500, 50),
           ['{}'.format(int(abs(x))) if x != 0 else 0 for x in np.arange(0, 500, 50)])
plt.xlabel('prime genre')
plt.ylabel('Number of comments')

plt.savefig('pop_pyramid_grouped.pdf')
;
# Out:
# ''

# %%
data['Male_Pct'] = data['0'] / data['COUNT']
data['Female_Pct'] = data['5'] / data['COUNT']

plt.figure(figsize=(15, 7))

for (i, row) in data.iterrows():
    plt.bar([i], [row['Male_Pct']],
            color=['#008AB8'], width=0.9, align='center', edgecolor='none')
    plt.bar([i], [row['Female_Pct']], bottom=[row['Male_Pct']],
            color=['#CC6699'], width=0.9, align='center', edgecolor='none')
    
plt.xlim(-0.6, 20.6)
plt.ylim(0, 1)
plt.xticks(range(0, 21), data['NAME'], fontsize=11, rotation=45)
plt.grid(False)
plt.yticks(np.arange(0, 1.01, 0.25),
           ['{}%'.format(int(x * 100)) for x in np.arange(0, 1.01, 0.25)])
plt.xlabel('prime genre')
plt.ylabel('Number of comments')

plt.plot([-0.425, 20.425], [0.5, 0.5], lw=2, color='black')
plt.plot([-0.425, 20.425], [0.25, 0.25], lw=2, color='black')

plt.savefig('pop_pyramid_stacked.pdf')
;
# Out:
# ''
